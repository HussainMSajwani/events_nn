# %%
import numpy as np
import h5py 
from pathlib import Path

GEN1_DIR = Path('/media/hussain/28E9086A116E859E/gen1/raw')
train_dir = GEN1_DIR / 'train/'

#sample point
sample_id = '17-03-30_12-53-58_500000_60500000'
events = h5py.File(train_dir / (sample_id + '_td.dat.h5'), 'r')
bbox = np.load(train_dir / (sample_id + '_bbox.npy'))

# %%
bbox
# Out:
# array([( 5099999,  64., 133., 146., 100., 0, 1.,  0),
#        ( 6099999,  65., 133., 144.,  93., 0, 1.,  1),
#        ( 7099999,  64., 133., 145.,  92., 0, 1.,  2),
#        ( 8099999,  65., 131., 143.,  98., 0, 1.,  3),
#        ( 9099999,  66., 131., 145.,  94., 0, 1.,  4),
#        (10099999,  67., 131., 145.,  95., 0, 1.,  5),
#        (11099999,  69., 132., 145.,  94., 0, 1.,  6),
#        (12099999,  82., 132., 149.,  97., 0, 1.,  7),
#        (13099999, 107., 133., 156., 100., 0, 1.,  8),
#        (13099999,   4., 129.,  21.,  29., 1, 1.,  9),
#        (14099999, 127., 132., 173., 105., 0, 1., 10),
#        (15099999, 161., 132., 157., 113., 0, 1., 11),
#        (16099999, 194., 131., 135., 108., 0, 1., 12),
#        (17099999, 195., 131., 138., 106., 0, 1., 13),
#        (18099999, 200., 132., 140., 105., 0, 1., 14),
#        (19099999, 210., 134., 137., 107., 0, 1., 15),
#        (20099999, 216., 133., 133., 104., 0, 1., 16),
# ...
